# %%
from teradataml import *
import sys
import getpass
import logging


logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
import matplotlib.pyplot as plt
from collections import Counter

# %%
host = 'vantage24.td.teradata.com'
username = 'AJ255081'
password = getpass.getpass("Password: ")

eng = create_context(host=host, username=username, password=password, logmech="TDNEGO")
conn = eng.connect()

# configure byom/val installation
configure.val_install_location = 'val'
configure.byom_install_location = 'mldb'

# %%
db_list_tables()
# Out:
# c:\Users\aj255081\AppData\Local\miniconda3\envs\mlops_kt\lib\site-packages\teradataml\dbutils\dbutils.py:333: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pddf = pd.read_sql(query, tdmlctx.td_connection.connection)
# c:\Users\aj255081\AppData\Local\miniconda3\envs\mlops_kt\lib\site-packages\teradataml\dbutils\dbutils.py:339: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vtdf = pd.read_sql(vtquery, tdmlctx.td_connection.connection)
#                   TableName
# 0           aoa_byom_models
# 1   aoa_statistics_metadata
# 2  pima_patient_predictions
# 3    pima_patient_diagnoses
# 4     pima_patient_features

# %%
DataFrame("pima_patient_diagnoses")
# Out:
#            HasDiabetes
# PatientId
# 343                  0
# 28                   0
# 476                  1
# 367                  0
# 712                  1
# 39                   1
# 447                  0
# 648                  1
# 282                  0
# 671                  0

# %%
train_df = DataFrame.from_query("""
    SEL f.*, d.HasDiabetes 
    FROM aj255081.pima_patient_features f
    INNER JOIN aj255081.pima_patient_diagnoses d
        ON f.PatientId = d.PatientId;
""")
train_df
# Out:
#    PatientId  NumTimesPrg  PlGlcConc  BloodP  SkinThick  TwoHourSerIns   BMI  DiPedFunc  Age  HasDiabetes
# 0        467            0         97      64         36            100  36.8      0.600   25            0
# 1        406            4        115      72          0              0  28.9      0.376   46            1
# 2        507            1        130      60         23            170  28.6      0.692   21            0
# 3        753            0        181      88         44            510  43.3      0.222   26            1
# 4        122            2        107      74         30            100  33.6      0.404   23            0
# 5        671            1         99      58         10              0  25.4      0.551   21            0
# 6        326            1        122      64         32            156  35.1      0.692   30            1
# 7        703            2        129       0          0              0  38.5      0.304   41            0
# 8        141            5        106      82         30              0  39.5      0.286   38            0
# 9        530            2        122      60         18            106  29.8      0.717   22            0

# %%
feature_names = ['NumTimesPrg', 'PlGlcConc', 'BloodP', 'SkinThick', 'TwoHourSerIns', 'BMI', 'DiPedFunc', 'Age']
target_name = 'HasDiabetes'
entity_key = 'PatientId'

scale_method = 'RANGE'
miss_value = 'KEEP'
global_scale = False
multiplier = "1"
intercept = "0"

scaler = ScaleFit(
    data=train_df,
    target_columns=feature_names,
    scale_method=scale_method,
    miss_value=miss_value,
    global_scale=global_scale,
    multiplier=multiplier,
    intercept=intercept
)

# %%
scaled_train = ScaleTransform(
    data=train_df,
    object=scaler.output,
    accumulate=[target_name, entity_key]
)

# %%
tree_type = 'CLASSIFICATION'
max_depth = 12
num_trees = 4

model = DecisionForest(
    data=scaled_train.result,
    input_columns=feature_names,
    response_column=target_name,
    tree_type=tree_type,
    max_depth=max_depth  
)

# %%
model_pdf = model.result.to_pandas()['classification_tree']

# %%
def traverse_tree(tree, feature_counter):
    if 'split_' in tree and 'attr_' in tree['split_']:
        feature_counter[tree['split_']['attr_']] += 1
    if 'leftChild_' in tree:
        traverse_tree(tree['leftChild_'], feature_counter)
    if 'rightChild_' in tree:
        traverse_tree(tree['rightChild_'], feature_counter)


def compute_feature_importance(trees_json):
    feature_counter = Counter()
    for tree_json in trees_json:
        tree = json.loads(tree_json)
        traverse_tree(tree, feature_counter)
    total_splits = sum(feature_counter.values())
    feature_importance = {
        feature: count / total_splits for feature, count in feature_counter.items()}
    return feature_importance


def plot_feature_importance(fi, img_filename):
    feat_importances = pd.Series(fi)
    feat_importances.nlargest(10).plot(
        kind='barh').set_title('Feature Importance')
    fig = plt.gcf()
    fig.savefig(img_filename, dpi=500)
    plt.clf()

# %%
feature_importance = compute_feature_importance(model_pdf)
feature_importance
# Out:
# {'Age': 0.10638297872340426,
#  'SkinThick': 0.09574468085106383,
#  'BMI': 0.09574468085106383,
#  'PlGlcConc': 0.35106382978723405,
#  'BloodP': 0.10638297872340426,
#  'NumTimesPrg': 0.14893617021276595,
#  'TwoHourSerIns': 0.05319148936170213,
#  'DiPedFunc': 0.0425531914893617}

# %%
plot_feature_importance(
        feature_importance, "feat_imp")

# %%
model
# Out:
# ############ result Output ############
#
#    task_index  tree_num  tree_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 classification_tree
# 0           2         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {"id_":1,"size_":17,"maxDepth_":12,"responseCounts_":{"0":6,"1":11},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.575377,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.456747,"scoreImprove_":0.348904,"leftNodeSize_":5,"rightNodeSize_":12},"leftChild_":{"id_":2,"size_":5,"maxDepth_":11,"label_":"0","responseCounts_":{"0":5},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":12,"maxDepth_":11,"responseCounts_":{"1":11,"0":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.459596,"attr_":"SkinThick","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.152778,"scoreImprove_":0.107843,"leftNodeSize_":11,"rightNodeSize_":1},"leftChild_":{"id_":6,"size_":11,"maxDepth_":10,"label_":"1","responseCounts_":{"1":11},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":7,"size_":1,"maxDepth_":10,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"}}}
# 1           6         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {"id_":1,"size_":31,"maxDepth_":12,"responseCounts_":{"0":23,"1":8},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.620603,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.382934,"scoreImprove_":0.325587,"leftNodeSize_":22,"rightNodeSize_":9},"leftChild_":{"id_":2,"size_":22,"maxDepth_":11,"label_":"0","responseCounts_":{"0":22},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":9,"maxDepth_":11,"responseCounts_":{"1":8,"0":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.451565,"attr_":"BMI","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.197531,"scoreImprove_":0.057348,"leftNodeSize_":1,"rightNodeSize_":8},"leftChild_":{"id_":6,"size_":1,"maxDepth_":10,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":7,"size_":8,"maxDepth_":10,"label_":"1","responseCounts_":{"1":8},"nodeType_":"CLASSIFICATION_LEAF"}}}
# 2           9         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {"id_":1,"size_":26,"maxDepth_":12,"responseCounts_":{"0":10,"1":16},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.819095,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.473373,"scoreImprove_":0.345168,"leftNodeSize_":12,"rightNodeSize_":14},"leftChild_":{"id_":2,"size_":12,"maxDepth_":11,"responseCounts_":{"1":2,"0":10},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.456781,"attr_":"BMI","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.277778,"scoreImprove_":0.076923,"leftNodeSize_":9,"rightNodeSize_":3},"leftChild_":{"id_":4,"size_":9,"maxDepth_":10,"label_":"0","responseCounts_":{"0":9},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":5,"size_":3,"maxDepth_":10,"responseCounts_":{"0":1,"1":2},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.147059,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.444444,"scoreImprove_":0.051282,"leftNodeSize_":1,"rightNodeSize_":2},"leftChild_":{"id_":10,"size_":1,"maxDepth_":9,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":11,"size_":2,"maxDepth_":9,"label_":"1","responseCounts_":{"1":2},"nodeType_":"CLASSIFICATION_LEAF"}}},"rightChild_":{"id_":3,"size_":14,"maxDepth_":11,"label_":"1","responseCounts_":{"1":14},"nodeType_":"CLASSIFICATION_LEAF"}}
# 3          10         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {"id_":1,"size_":25,"maxDepth_":12,"responseCounts_":{"0":23,"1":2},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.647541,"attr_":"BloodP","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.147200,"scoreImprove_":0.147200,"leftNodeSize_":23,"rightNodeSize_":2},"leftChild_":{"id_":2,"size_":23,"maxDepth_":11,"label_":"0","responseCounts_":{"0":23},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":2,"maxDepth_":11,"label_":"1","responseCounts_":{"1":2},"nodeType_":"CLASSIFICATION_LEAF"}}
# 4           8         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                   {"id_":1,"size_":26,"maxDepth_":12,"responseCounts_":{"0":17,"1":9},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.495529,"attr_":"BMI","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.452663,"scoreImprove_":0.256509,"leftNodeSize_":20,"rightNodeSize_":6},"leftChild_":{"id_":2,"size_":20,"maxDepth_":11,"responseCounts_":{"1":3,"0":17},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.663934,"attr_":"BloodP","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.255000,"scoreImprove_":0.123504,"leftNodeSize_":18,"rightNodeSize_":2},"leftChild_":{"id_":4,"size_":18,"maxDepth_":10,"responseCounts_":{"0":17,"1":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.237374,"attr_":"SkinThick","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.104938,"scoreImprove_":0.011111,"leftNodeSize_":13,"rightNodeSize_":5},"leftChild_":{"id_":8,"size_":13,"maxDepth_":9,"label_":"0","responseCounts_":{"0":13},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":9,"size_":5,"maxDepth_":9,"responseCounts_":{"1":1,"0":4},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.382353,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.320000,"scoreImprove_":0.061538,"leftNodeSize_":4,"rightNodeSize_":1},"leftChild_":{"id_":18,"size_":4,"maxDepth_":8,"label_":"0","responseCounts_":{"0":4},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":19,"size_":1,"maxDepth_":8,"label_":"1","responseCounts_":{"1":1},"nodeType_":"CLASSIFICATION_LEAF"}}},"rightChild_":{"id_":5,"size_":2,"maxDepth_":10,"label_":"1","responseCounts_":{"1":2},"nodeType_":"CLASSIFICATION_LEAF"}},"rightChild_":{"id_":3,"size_":6,"maxDepth_":11,"label_":"1","responseCounts_":{"1":6},"nodeType_":"CLASSIFICATION_LEAF"}}
# 5          11         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {"id_":1,"size_":17,"maxDepth_":12,"responseCounts_":{"0":7,"1":10},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.575377,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.484429,"scoreImprove_":0.381488,"leftNodeSize_":8,"rightNodeSize_":9},"leftChild_":{"id_":2,"size_":8,"maxDepth_":11,"responseCounts_":{"1":1,"0":7},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.236181,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.218750,"scoreImprove_":0.102941,"leftNodeSize_":1,"rightNodeSize_":7},"leftChild_":{"id_":4,"size_":1,"maxDepth_":10,"label_":"1","responseCounts_":{"1":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":5,"size_":7,"maxDepth_":10,"label_":"0","responseCounts_":{"0":7},"nodeType_":"CLASSIFICATION_LEAF"}},"rightChild_":{"id_":3,"size_":9,"maxDepth_":11,"label_":"1","responseCounts_":{"1":9},"nodeType_":"CLASSIFICATION_LEAF"}}
# 6          12         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {"id_":1,"size_":27,"maxDepth_":12,"responseCounts_":{"0":20,"1":7},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.846734,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.384088,"scoreImprove_":0.249408,"leftNodeSize_":22,"rightNodeSize_":5},"leftChild_":{"id_":2,"size_":22,"maxDepth_":11,"responseCounts_":{"1":2,"0":20},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.561848,"attr_":"BMI","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.165289,"scoreImprove_":0.045791,"leftNodeSize_":17,"rightNodeSize_":5},"leftChild_":{"id_":4,"size_":17,"maxDepth_":10,"label_":"0","responseCounts_":{"0":17},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":5,"size_":5,"maxDepth_":10,"responseCounts_":{"0":3,"1":2},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.575377,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.480000,"scoreImprove_":0.088889,"leftNodeSize_":2,"rightNodeSize_":3},"leftChild_":{"id_":10,"size_":2,"maxDepth_":9,"label_":"1","responseCounts_":{"1":2},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":11,"size_":3,"maxDepth_":9,"label_":"0","responseCounts_":{"0":3},"nodeType_":"CLASSIFICATION_LEAF"}}},"rightChild_":{"id_":3,"size_":5,"maxDepth_":11,"label_":"1","responseCounts_":{"1":5},"nodeType_":"CLASSIFICATION_LEAF"}}
# 7           4         0           0  {"id_":1,"size_":35,"maxDepth_":12,"responseCounts_":{"0":27,"1":8},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.678392,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.352653,"scoreImprove_":0.198367,"leftNodeSize_":30,"rightNodeSize_":5},"leftChild_":{"id_":2,"size_":30,"maxDepth_":11,"responseCounts_":{"1":3,"0":27},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.684426,"attr_":"BloodP","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.180000,"scoreImprove_":0.061164,"leftNodeSize_":27,"rightNodeSize_":3},"leftChild_":{"id_":4,"size_":27,"maxDepth_":10,"responseCounts_":{"0":26,"1":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.630653,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.071331,"scoreImprove_":0.026455,"leftNodeSize_":25,"rightNodeSize_":2},"leftChild_":{"id_":8,"size_":25,"maxDepth_":9,"label_":"0","responseCounts_":{"0":25},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":9,"size_":2,"maxDepth_":9,"responseCounts_":{"1":1,"0":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.117647,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.500000,"scoreImprove_":0.028571,"leftNodeSize_":1,"rightNodeSize_":1},"leftChild_":{"id_":18,"size_":1,"maxDepth_":8,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":19,"size_":1,"maxDepth_":8,"label_":"1","responseCounts_":{"1":1},"nodeType_":"CLASSIFICATION_LEAF"}}},"rightChild_":{"id_":5,"size_":3,"maxDepth_":10,"responseCounts_":{"0":1,"1":2},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.294118,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.444444,"scoreImprove_":0.038095,"leftNodeSize_":2,"rightNodeSize_":1},"leftChild_":{"id_":10,"size_":2,"maxDepth_":9,"label_":"1","responseCounts_":{"1":2},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":11,"size_":1,"maxDepth_":9,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"}}},"rightChild_":{"id_":3,"size_":5,"maxDepth_":11,"label_":"1","responseCounts_":{"1":5},"nodeType_":"CLASSIFICATION_LEAF"}}
# 8          13         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {"id_":1,"size_":18,"maxDepth_":12,"responseCounts_":{"0":11,"1":7},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.796482,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.475309,"scoreImprove_":0.475309,"leftNodeSize_":11,"rightNodeSize_":7},"leftChild_":{"id_":2,"size_":11,"maxDepth_":11,"label_":"0","responseCounts_":{"0":11},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":7,"maxDepth_":11,"label_":"1","responseCounts_":{"1":7},"nodeType_":"CLASSIFICATION_LEAF"}}
# 9          14         0           0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {"id_":1,"size_":25,"maxDepth_":12,"responseCounts_":{"0":17,"1":8},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.703518,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.435200,"scoreImprove_":0.435200,"leftNodeSize_":17,"rightNodeSize_":8},"leftChild_":{"id_":2,"size_":17,"maxDepth_":11,"label_":"0","responseCounts_":{"0":17},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":8,"maxDepth_":11,"label_":"1","responseCounts_":{"1":8},"nodeType_":"CLASSIFICATION_LEAF"}}

# %%
model_pdf
# Out:
# 0     {"id_":1,"size_":22,"maxDepth_":12,"responseCo...
# 1     {"id_":1,"size_":26,"maxDepth_":12,"responseCo...
# 2     {"id_":1,"size_":17,"maxDepth_":12,"responseCo...
# 3     {"id_":1,"size_":18,"maxDepth_":12,"responseCo...
# 4     {"id_":1,"size_":35,"maxDepth_":12,"responseCo...
# 5     {"id_":1,"size_":17,"maxDepth_":12,"responseCo...
# 6     {"id_":1,"size_":31,"maxDepth_":12,"responseCo...
# 7     {"id_":1,"size_":31,"maxDepth_":12,"responseCo...
# 8     {"id_":1,"size_":26,"maxDepth_":12,"responseCo...
# 9     {"id_":1,"size_":26,"maxDepth_":12,"responseCo...
# 10    {"id_":1,"size_":25,"maxDepth_":12,"responseCo...
# 11    {"id_":1,"size_":17,"maxDepth_":12,"responseCo...
# 12    {"id_":1,"size_":27,"maxDepth_":12,"responseCo...
# 13    {"id_":1,"size_":18,"maxDepth_":12,"responseCo...
# 14    {"id_":1,"size_":25,"maxDepth_":12,"responseCo...
# 15    {"id_":1,"size_":25,"maxDepth_":12,"responseCo...
# 16    {"id_":1,"size_":28,"maxDepth_":12,"responseCo...
# 17    {"id_":1,"size_":29,"maxDepth_":12,"responseCo...
# 18    {"id_":1,"size_":28,"maxDepth_":12,"responseCo...
# 19    {"id_":1,"size_":29,"maxDepth_":12,"responseCo...
# 20    {"id_":1,"size_":31,"maxDepth_":12,"responseCo...
# 21    {"id_":1,"size_":31,"maxDepth_":12,"responseCo...
# 22    {"id_":1,"size_":26,"maxDepth_":12,"responseCo...
# 23    {"id_":1,"size_":27,"maxDepth_":12,"responseCo...
# 24    {"id_":1,"size_":27,"maxDepth_":12,"responseCo...
# 25    {"id_":1,"size_":18,"maxDepth_":12,"responseCo...
# 26    {"id_":1,"size_":19,"maxDepth_":12,"responseCo...
# 27    {"id_":1,"size_":27,"maxDepth_":12,"responseCo...
# 28    {"id_":1,"size_":25,"maxDepth_":12,"responseCo...
# 29    {"id_":1,"size_":28,"maxDepth_":12,"responseCo...
# 30    {"id_":1,"size_":19,"maxDepth_":12,"responseCo...
# 31    {"id_":1,"size_":25,"maxDepth_":12,"responseCo...
# 32    {"id_":1,"size_":26,"maxDepth_":12,"responseCo...
# 33    {"id_":1,"size_":28,"maxDepth_":12,"responseCo...
# 34    {"id_":1,"size_":22,"maxDepth_":12,"responseCo...
# Name: classification_tree, dtype: object

# %%
type(str("False").lower() in ['true', '1'])
# Out:
# bool

# %%
predictions = TDDecisionForestPredict(
        object=model,
        newdata=scaled_train.result,
        accumulate=target_name,
        id_column=entity_key,
        output_prob=True,
        output_responses=['0', '1']
    )

# %%
predictions.result.dtypes
# Out:
# PatientId        int
# prediction       int
# prob_0         float
# prob_1         float
# HasDiabetes      int

# %%
ClassificationEvaluator_obj = ClassificationEvaluator(
        data=predictions.result,
        observation_column=target_name,
        prediction_column='prediction',
        num_labels=2
    )

# %%
metrics_pd = ClassificationEvaluator_obj.output_data.to_pandas()

evaluation = {
        'Accuracy': '{:.2f}'.format(metrics_pd.MetricValue[0]),
        'Micro-Precision': '{:.2f}'.format(metrics_pd.MetricValue[1]),
        'Micro-Recall': '{:.2f}'.format(metrics_pd.MetricValue[2]),
        'Micro-F1': '{:.2f}'.format(metrics_pd.MetricValue[3]),
        'Macro-Precision': '{:.2f}'.format(metrics_pd.MetricValue[4]),
        'Macro-Recall': '{:.2f}'.format(metrics_pd.MetricValue[5]),
        'Macro-F1': '{:.2f}'.format(metrics_pd.MetricValue[6]),
        'Weighted-Precision': '{:.2f}'.format(metrics_pd.MetricValue[7]),
        'Weighted-Recall': '{:.2f}'.format(metrics_pd.MetricValue[8]),
        'Weighted-F1': '{:.2f}'.format(metrics_pd.MetricValue[9]),
}
evaluation
# Out:
# {'Accuracy': '0.77',
#  'Micro-Precision': '0.77',
#  'Micro-Recall': '0.77',
#  'Micro-F1': '0.77',
#  'Macro-Precision': '0.76',
#  'Macro-Recall': '0.72',
#  'Macro-F1': '0.73',
#  'Weighted-Precision': '0.76',
#  'Weighted-Recall': '0.77',
#  'Weighted-F1': '0.76'}

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cf, img_filename):
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots(figsize=(7.5, 7.5))
    ax.matshow(cf, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(cf.shape[0]):
        for j in range(cf.shape[1]):
            ax.text(x=j, y=i, s=cf[i, j], va='center',
                    ha='center', size='xx-large')
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix')
    fig = plt.gcf()
    fig.savefig(img_filename, dpi=500)
    plt.clf()


def plot_roc_curve(roc_out, img_filename):
    import matplotlib.pyplot as plt
    auc = roc_out.result.to_pandas().reset_index()['AUC'][0]
    roc_results = roc_out.output_data.to_pandas()
    plt.plot(roc_results['fpr'], roc_results['tpr'],
             color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % 0.27)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    fig = plt.gcf()
    fig.savefig(img_filename, dpi=500)
    plt.clf()

# %%
cm = confusion_matrix(predictions.result.to_pandas()[
                          'HasDiabetes'], predictions.result.to_pandas()['prediction'])

plot_confusion_matrix(
        cm, "confusion_matrix")

# %%
roc_out = ROC(
        data=predictions.result,
        probability_column='prob_1',
        observation_column=target_name,
        positive_class='1',
        num_thresholds=1000
    )

plot_roc_curve(roc_out, "roc_curve")

# %%
try:
        model_pdf = model.result.to_pandas()['classification_tree']
        feature_importance = compute_feature_importance(model_pdf)
        feature_importance_df = pd.DataFrame(
            list(feature_importance.items()), columns=['Feature', 'Importance'])
        plot_feature_importance(
            feature_importance, "feature_importance_eval")
except:
        feature_importance = {}

# %%
predictions_pdf = predictions.result.to_pandas(all_rows=True).rename(
        columns={"prediction": target_name}).astype(int)
predictions_pdf
# Out:
#      PatientId  HasDiabetes  prob_0  prob_1  HasDiabetes
# 0          221            1       0       0            1
# 1          265            0       0       0            0
# 2          461            0       0       0            0
# 3          713            0       0       0            0
# 4          242            0       0       0            1
# ..         ...          ...     ...     ...          ...
# 763         46            0       0       0            0
# 764        227            1       0       0            1
# 765        717            0       0       0            0
# 766        225            0       0       0            0
# 767        347            0       0       0            0
#
# [768 rows x 5 columns]

# %%
predictions = TDDecisionForestPredict(
        object=model,
        newdata=scaled_train.result,
        id_column=entity_key,
        output_prob=True,
        output_responses=['0', '1']
    )
predictions_pdf = predictions.result.to_pandas(all_rows=True).rename(
        columns={"prediction": target_name}).astype(int)
predictions_pdf = pd.DataFrame(predictions_pdf, columns=[target_name])

# %%
predictions_pdf
# Out:
#      HasDiabetes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 763            0
# 764            1
# 765            0
# 766            0
# 767            0
#
# [768 rows x 1 columns]

# %%
display_analytic_functions()
# Out:
# List of available functions:
#
# 	Analytics Database Functions:
# 		* MODEL SCORING functions:
# 			 1. DecisionTreePredict
# 			 2. GLMPredictPerSegment
# 			 3. KMeansPredict
# 			 4. NaiveBayesPredict
# 			 5. OneClassSVMPredict
# 			 6. SVMPredict
# 			 7. TDDecisionForestPredict
# 			 8. TDGLMPredict
# 			 9. TDNaiveBayesPredict
# 			 10. XGBoostPredict
# 		* FEATURE ENGINEERING TRANSFORM functions:
# 			 1. Antiselect
# 			 2. BincodeFit
# 			 3. BincodeTransform
# 			 4. ColumnTransformer
# 			 5. Fit
# 			 6. NonLinearCombineFit
# 			 7. NonLinearCombineTransform
# 			 8. OneHotEncodingFit
# 			 9. OneHotEncodingTransform
# 			 10. OrdinalEncodingFit
# 			 11. OrdinalEncodingTransform
# 			 12. Pivoting
# 			 13. PolynomialFeaturesFit
# 			 14. PolynomialFeaturesTransform
# 			 15. RandomProjectionFit
# 			 16. RandomProjectionMinComponents
# 			 17. RandomProjectionTransform
# 			 18. RowNormalizeFit
# 			 19. RowNormalizeTransform
# 			 20. ScaleFit
# 			 21. ScaleTransform
# 			 22. TargetEncodingFit
# 			 23. TargetEncodingTransform
# 			 24. TFIDF
# 			 25. Transform
# 			 26. Unpivoting
# 		* PATH AND PATTERN ANALYSIS functions:
# 			 1. Attribution
# 			 2. NPath
# 			 3. Sessionize
# 		* SCORING WITH MACHINE LEARNING ENGINE MODELS functions:
# 			 1. DecisionForestPredict
# 			 2. GLMPredict
# 			 3. NaiveBayesTextClassifierPredict
# 			 4. SVMSparsePredict
# 		* DATA EXPLORATION functions:
# 			 1. CategoricalSummary
# 			 2. ColumnSummary
# 			 3. GetRowsWithMissingValues
# 			 4. Histogram
# 			 5. MovingAverage
# 			 6. QQNorm
# 			 7. UnivariateStatistics
# 			 8. WhichMax
# 			 9. WhichMin
# 		* TEXT ANALYTIC functions:
# 			 1. NaiveBayesTextClassifierTrainer
# 			 2. NGramSplitter
# 			 3. SentimentExtractor
# 			 4. TextParser
# 			 5. WordEmbeddings
# 		* DATA CLEANING functions:
# 			 1. ConvertTo
# 			 2. GetFutileColumns
# 			 3. GetRowsWithoutMissingValues
# 			 4. OutlierFilterFit
# 			 5. OutlierFilterTransform
# 			 6. Pack
# 			 7. SimpleImputeFit
# 			 8. SimpleImputeTransform
# 			 9. StringSimilarity
# 			 10. Unpack
# 		* HYPOTHESIS TESTING functions:
# 			 1. ANOVA
# 			 2. ChiSq
# 			 3. FTest
# 			 4. ZTest
# 		* ASSOCIATION ANALYSIS functions:
# 			 1. CFilter
# 		* MODEL EVALUATION functions:
# 			 1. ClassificationEvaluator
# 			 2. RegressionEvaluator
# 			 3. ROC
# 			 4. Silhouette
# 			 5. TrainTestSplit
# 		* MODEL TRAINING functions:
# 			 1. DecisionForest
# 			 2. GLM
# 			 3. GLMPerSegment
# 			 4. KMeans
# 			 5. KNN
# 			 6. NaiveBayes
# 			 7. OneClassSVM
# 			 8. SVM
# 			 9. VectorDistance
# 			 10. XGBoost
# 		* FEATURE ENGINEERING UTILITY functions:
# 			 1. FillRowId
# 			 2. NumApply
# 			 3. RoundColumns
# 			 4. StrApply
# 		* MODEL INTERPRETATION functions:
# 			 1. Shap
#
# 	Unbounded Array Framework (UAF) Functions:
# 		* MODEL PREPARATION AND PARAMETER ESTIMATION functions:
# 			 1. ACF
# 			 2. ArimaEstimate
# 			 3. ArimaValidate
# 			 4. ArimaXEstimate
# 			 5. AutoArima
# 			 6. DIFF
# 			 7. LinearRegr
# 			 8. MultivarRegr
# 			 9. PACF
# 			 10. PowerTransform
# 			 11. SeasonalNormalize
# 			 12. Smoothma
# 			 13. UNDIFF
# 			 14. Unnormalize
# 		* SERIES FORECASTING functions:
# 			 1. ArimaForecast
# 			 2. DTW
# 			 3. HoltWintersForecaster
# 			 4. MAMean
# 			 5. SimpleExp
# 		* DATA PREPARATION functions:
# 			 1. BinaryMatrixOp
# 			 2. BinarySeriesOp
# 			 3. GenseriesFormula
# 			 4. MatrixMultiply
# 			 5. Resample
# 		* DIAGNOSTIC STATISTICAL TEST functions:
# 			 1. BreuschGodfrey
# 			 2. BreuschPaganGodfrey
# 			 3. CumulPeriodogram
# 			 4. DickeyFuller
# 			 5. DurbinWatson
# 			 6. FitMetrics
# 			 7. GoldfeldQuandt
# 			 8. Portman
# 			 9. SelectionCriteria
# 			 10. SignifPeriodicities
# 			 11. SignifResidmean
# 			 12. WhitesGeneral
# 		* TEMPORAL AND SPATIAL functions:
# 			 1. Convolve
# 			 2. Convolve2
# 			 3. DFFT
# 			 4. DFFT2
# 			 5. DFFT2Conv
# 			 6. DFFTConv
# 			 7. GenseriesSinusoids
# 			 8. IDFFT
# 			 9. IDFFT2
# 			 10. LineSpec
# 			 11. PowerSpec
# 		* DIGITAL SIGNAL PROCESSING functions:
# 			 1. DWT
# 			 2. DWT2D
# 			 3. IDWT
# 			 4. IDWT2D
# 			 5. SAX
# 			 6. WindowDFFT
# 		* GENERAL UTILITY functions:
# 			 1. CopyArt
# 			 2. ExtractResults
# 			 3. FilterFactory1d
# 			 4. InputValidator
# 			 5. Matrix2Image
# 			 6. MInfo
# 			 7. SInfo
# 			 8. TrackingOp
# 		* ANOMALY DETECTION functions:
# 			 1. IQR
#
# 	TABLE OPERATOR Functions:
# 		 1. Image2Matrix
# 		 2. ReadNOS
# 		 3. WriteNOS
#
# 	BYOM Functions:
# 		 1. DataikuPredict
# 		 2. DataRobotPredict
# 		 3. H2OPredict
# 		 4. ONNXPredict
# 		 5. PMMLPredict
#
# 	Vantage Analytic Library (VAL) Functions:
# 		* DESCRIPTIVE STATISTICS functions:
# 			 1. AdaptiveHistogram
# 			 2. Explore
# 			 3. Frequency
# 			 4. Histogram
# 			 5. Overlap
# 			 6. Statistics
# 			 7. TextAnalyzer
# 			 8. Values
# 		* VARIABLE TRANSFORMATION functions:
# 			 1. BinCode
# 			 2. Derive
# 			 3. DesignCode
# 			 4. Fillna
# 			 5. Recode
# 			 6. Rescale
# 			 7. Retain
# 			 8. Sigmoid
# 			 9. Transform
# 			 10. ZScore
# 		* STATISTICAL TEST functions:
# 			 1. BinomialTest
# 			 2. ChiSquareTest
# 			 3. KSTest
# 			 4. ParametricTest
# 			 5. RankTest
# 		* MODEL TRAINING functions:
# 			 1. Association
# 			 2. DecisionTree
# 			 3. KMeans
# 			 4. LinReg
# 			 5. LogReg
# 			 6. Matrix
# 			 7. PCA
# 		* MODEL SCORING/PREDICTION functions:
# 			 1. DecisionTreeEvaluator
# 			 2. DecisionTreePredict
# 			 3. KMeansPredict
# 			 4. LinRegEvaluator
# 			 5. LinRegPredict
# 			 6. LogRegEvaluator
# 			 7. LogRegPredict
# 			 8. PCAEvaluator
# 			 9. PCAPredict
# 		* HELPER functions:
# 			 1. XmlToHtmlReport

# %%
DataFrame.from_query(f"""
        SELECT 
            * 
        FROM  pima_patient_predictions
        WHERE job_id = '9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb'
""")
# Out:
#                                       PatientId  HasDiabetes json_report
# job_id
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          2            1
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          4            0
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          5            0
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          6            1
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          8            0
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          9            1
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          7            1
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          3            1
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          1            0
# 9eaf64a6-d044-4c7b-8ad1-ad06f6a63efb          0            1

# %%
DataFrame.from_query(f"""
        SELECT 
            * 
        FROM  "model_07f434ff-2a0a-45c6-8a65-d65b18cfc4aa"
""")
# Out:
#    task_index  tree_num  tree_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            classification_tree
# 0          21         0           0                                                                                                                                                                                                                                                                                                                                                                                                                            {"id_":1,"size_":15,"maxDepth_":12,"responseCounts_":{"0":11,"1":4},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.448980,"attr_":"Age","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.391111,"scoreImprove_":0.391111,"leftNodeSize_":11,"rightNodeSize_":4},"leftChild_":{"id_":2,"size_":11,"maxDepth_":11,"label_":"0","responseCounts_":{"0":11},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":4,"maxDepth_":11,"label_":"1","responseCounts_":{"1":4},"nodeType_":"CLASSIFICATION_LEAF"}}
# 1          22         0           0                                                                                                                                                                                                                                                                                                                                                                                                                         {"id_":1,"size_":4,"maxDepth_":12,"responseCounts_":{"0":3,"1":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.153846,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.375000,"scoreImprove_":0.375000,"leftNodeSize_":3,"rightNodeSize_":1},"leftChild_":{"id_":2,"size_":3,"maxDepth_":11,"label_":"0","responseCounts_":{"0":3},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":1,"maxDepth_":11,"label_":"1","responseCounts_":{"1":1},"nodeType_":"CLASSIFICATION_LEAF"}}
# 2          26         0           0  {"id_":1,"size_":8,"maxDepth_":12,"responseCounts_":{"0":2,"1":6},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.824074,"attr_":"SkinThick","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.375000,"scoreImprove_":0.208333,"leftNodeSize_":3,"rightNodeSize_":5},"leftChild_":{"id_":2,"size_":3,"maxDepth_":11,"responseCounts_":{"1":1,"0":2},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.266972,"attr_":"DiPedFunc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.444444,"scoreImprove_":0.166667,"leftNodeSize_":1,"rightNodeSize_":2},"leftChild_":{"id_":4,"size_":1,"maxDepth_":10,"label_":"1","responseCounts_":{"1":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":5,"size_":2,"maxDepth_":10,"label_":"0","responseCounts_":{"0":2},"nodeType_":"CLASSIFICATION_LEAF"}},"rightChild_":{"id_":3,"size_":5,"maxDepth_":11,"label_":"1","responseCounts_":{"1":5},"nodeType_":"CLASSIFICATION_LEAF"}}
# 3          13         0           0                                                                                                                                                                                                                                                                                                                                                                                                                         {"id_":1,"size_":9,"maxDepth_":12,"responseCounts_":{"0":2,"1":7},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.846154,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.345679,"scoreImprove_":0.345679,"leftNodeSize_":7,"rightNodeSize_":2},"leftChild_":{"id_":2,"size_":7,"maxDepth_":11,"label_":"1","responseCounts_":{"1":7},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":2,"maxDepth_":11,"label_":"0","responseCounts_":{"0":2},"nodeType_":"CLASSIFICATION_LEAF"}}
# 4           0         0           0                                                                                                                                                                                                                                                                                                                                                                                                                          {"id_":1,"size_":13,"maxDepth_":12,"responseCounts_":{"0":7,"1":6},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.605634,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.497041,"scoreImprove_":0.497041,"leftNodeSize_":7,"rightNodeSize_":6},"leftChild_":{"id_":2,"size_":7,"maxDepth_":11,"label_":"0","responseCounts_":{"0":7},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":6,"maxDepth_":11,"label_":"1","responseCounts_":{"1":6},"nodeType_":"CLASSIFICATION_LEAF"}}
# 5           2         0           0                                                                                                                                                                                                                                                                                                                                                                                                                           {"id_":1,"size_":4,"maxDepth_":12,"responseCounts_":{"0":1,"1":3},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.292254,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.375000,"scoreImprove_":0.375000,"leftNodeSize_":1,"rightNodeSize_":3},"leftChild_":{"id_":2,"size_":1,"maxDepth_":11,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":3,"maxDepth_":11,"label_":"1","responseCounts_":{"1":3},"nodeType_":"CLASSIFICATION_LEAF"}}
# 6           5         0           0                                                                                                                                                                                                                                                                                                                                                                                                                           {"id_":1,"size_":9,"maxDepth_":12,"responseCounts_":{"0":4,"1":5},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.503521,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.493827,"scoreImprove_":0.493827,"leftNodeSize_":4,"rightNodeSize_":5},"leftChild_":{"id_":2,"size_":4,"maxDepth_":11,"label_":"0","responseCounts_":{"0":4},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":5,"maxDepth_":11,"label_":"1","responseCounts_":{"1":5},"nodeType_":"CLASSIFICATION_LEAF"}}
# 7           4         0           0                                                                                                                                                                                                                                                                                                                                                                                                                          {"id_":1,"size_":10,"maxDepth_":12,"responseCounts_":{"0":1,"1":9},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.546296,"attr_":"SkinThick","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.180000,"scoreImprove_":0.180000,"leftNodeSize_":1,"rightNodeSize_":9},"leftChild_":{"id_":2,"size_":1,"maxDepth_":11,"label_":"0","responseCounts_":{"0":1},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":9,"maxDepth_":11,"label_":"1","responseCounts_":{"1":9},"nodeType_":"CLASSIFICATION_LEAF"}}
# 8           9         0           0                                                                                                                                                                                                                                                                                                                                                                                                                           {"id_":1,"size_":8,"maxDepth_":12,"responseCounts_":{"0":5,"1":3},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.327465,"attr_":"PlGlcConc","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.468750,"scoreImprove_":0.468750,"leftNodeSize_":5,"rightNodeSize_":3},"leftChild_":{"id_":2,"size_":5,"maxDepth_":11,"label_":"0","responseCounts_":{"0":5},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":3,"maxDepth_":11,"label_":"1","responseCounts_":{"1":3},"nodeType_":"CLASSIFICATION_LEAF"}}
# 9           7         0           0                                                                                                                                                                                                                                                                                                                                                                                                                         {"id_":1,"size_":8,"maxDepth_":12,"responseCounts_":{"0":7,"1":1},"nodeType_":"CLASSIFICATION_NODE","split_":{"splitValue_":0.461538,"attr_":"NumTimesPrg","type_":"CLASSIFICATION_NUMERIC_SPLIT","score_":0.218750,"scoreImprove_":0.218750,"leftNodeSize_":7,"rightNodeSize_":1},"leftChild_":{"id_":2,"size_":7,"maxDepth_":11,"label_":"0","responseCounts_":{"0":7},"nodeType_":"CLASSIFICATION_LEAF"},"rightChild_":{"id_":3,"size_":1,"maxDepth_":11,"label_":"1","responseCounts_":{"1":1},"nodeType_":"CLASSIFICATION_LEAF"}}
